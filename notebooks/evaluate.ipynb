# %%
import joblib
import numpy as np

# %%
model = joblib.load("../models/model.pkl")
# model = joblib.load("../models/model_pipe.pkl")

model
# Out:
# GradientBoostingRegressor(min_samples_leaf=2, min_samples_split=5,
#                           n_estimators=200, subsample=0.8)

# %%
x_test = np.load('../data/test_data.npy')
y_test = np.load('../data/test_target.npy')
x_test.shape
# Out:
# (1306, 7)

# %%
y_pred = model.predict(x_test)
y_pred
# Out:
# array([0.10090221, 0.14776936, 0.06276634, ..., 0.21010981, 0.02386567,
#        0.25985738])

# %%
y_test
# Out:
# array([0.128, 0.087, 0.069, ..., 0.204, 0.04 , 0.184])

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(list(range(y_test.shape[0])), y_test, label='y_true', c='b')
plt.scatter(list(range(y_test.shape[0])),y_pred, label='y_pred', c='g')
plt.legend()

# %%
plt.scatter(y_test, y_pred, c='b')
plt.plot(y_test, y_test, label='100% Accuracy', c='r')
plt.legend()
plt.title('Y true vs Y pred')
plt.xlabel('Y True')
plt.ylabel('Y Predicted')
# Out:
# Text(0, 0.5, 'Y Predicted')

# %%
plt.scatter(x_test[:,1], y_test, c='b')

# %%
plt.scatter(x_test[:,2], y_test, c='g')

# %%
plt.scatter(x_test[:,3], y_test)
